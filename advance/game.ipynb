# %%
from abc import ABC,abstractmethod
import random
class Games(ABC):
    def __init__(self,player_name):
        self.player_name = player_name
        self.score = 0
    @abstractmethod
    def play(self):
        pass
    def is_over(self):
        pass
class High_low(Games):
    def __init__(self,player_name,):
        self.count = 0
        self.score = 0
    def play(self):
        while self.count < 3:
          self.count += 1
          self.comp_num = random.randint(1,100)
          self.my_num = random.randint(1,100)
          print('your number is:',self.my_num)
          guess = input("guess weather your num is higher or lower then that of computer's num:")
          print('computer number is:',self.comp_num)
          if guess == 'higher' and self.my_num > self.comp_num:
            print('you are right!')
            self.score += 1
            print('your score is:',self.score)
          elif guess == 'lower' and self.my_num < self.comp_num:
              print('you are right!')
              self.score += 1
              print('your score is:',self.score)
          else:
                print('you are wrong')
                print('your score is',self.score)
        
        print('Thanks for playing')
        print('Good job! you played very well')
    def is_over(self):
        return self.count >=3

class GuessNumber(Games):
    def __init__(self, player_name):
       self.player_name = player_name
       self.user_attempt = 0
       self.allowed_attempt = 5
       self.game_over = False
    
    def play(self):
        num = random.randint(0,99)
        while self.user_attempt < self.allowed_attempt:
            print(f"{self.allowed_attempt}-{self.user_attempt}")
            self.user_attempt+=1
            guess = (int(input("enter your guess:")))
            print(guess)
            if self.user_attempt >= self.allowed_attempt:
                print(f"{self.player_name} you lost")
                break
            if guess == num:
                print("congrates your guess is correct")
                break
            elif guess< num:
                print(f"{self.player_name} your guess is too low")
            elif guess > num:
                print(f"{self.player_name} your guess is too high")
            else: 
                print("invalid input")
    def is_over(self):
        return self.game_over 
    
class Choose_game:
    def __init__(self):
        pass
    def game_choice():
        print("Welcome to the Game Engine!")
        print("1. High Low Game")
        print("2. Guess the Number Game")
        choice = input("Please choose a game (1 or 2): ")

        player_name = input("Enter your name: ")

        if choice == '1':
            game = High_low(player_name)
            game.play()
        elif choice == '2':
            game = GuessNumber(player_name)
            game.play()
        else:
            print("Invalid choice, please select 1 or 2.")
            game_choice()

    # Start the game engine
choose = Choose_game
choose.game_choice()
# Out:
# Welcome to the Game Engine!
# 1. High Low Game
# 2. Guess the Number Game
# 5-0
# 22
# 33 your guess is too high
# 5-1
# 33
# 33 your guess is too high
# 5-2
# 55
# 33 your guess is too high
# 5-3
# 67
# 33 your guess is too high
# 5-4
# 43
# 33 you lost

# %%
import random

class Game:
    def _init_(self, name, description):
        self.name = name
        self.description = description

    def get_info(self):
        print(f"Game: {self.name}")
        print(f"Description: {self.description}")

    def start(self):
        self.play()


class HighLow(Game):
    def _init_(self):
        super()._init_("High Low", "Guess if your number is higher than or lower than the computer's.")

    def play(self):
        self.game()

    def welcome_message(self):
        print("Welcome to the High-Low Game!")
        print("Guess if your number is higher or lower than the computer's.")

    def generate_numbers(self):
        # Generates a number for the player and the computer
        player_number = random.randint(1, 100)
        computer_number = random.randint(1, 100)
        return player_number, computer_number

    def get_player_guess(self):
        # Prompts the player for a guess
        guess = input("Do you think your number is 'higher' or 'lower' than the computer's number? ").strip().lower()
        return guess

    def check_guess(self, player_number, computer_number, guess):
        # Check if the player's guess is correct
        if guess == "higher":
            return player_number > computer_number
        elif guess == "lower":
            return player_number < computer_number
        else:
            print("Invalid guess. Please enter 'higher' or 'lower'.")
            return None

    def play_round(self):
        # Play a single round with consistent player and computer numbers
        player_number, computer_number = self.generate_numbers()
        print(f"\nYour number is: {player_number}")
        guess = self.get_player_guess()

        is_correct = self.check_guess(player_number, computer_number, guess)
        if is_correct is None:
            print("Invalid guess. Try again.")
            return False  # No points awarded for invalid input
        elif is_correct:
            print("Correct guess! You scored a point.")
            return True
        else:
            print("Incorrect guess.")
            print(f"The computer's number was: {computer_number}")  # Reveal computer's number after each guess
            return False

    def game(self):
        rounds = 5
        score = 0
        self.welcome_message()

        for round_num in range(1, rounds + 1):
            print(f"\nRound {round_num}")
            if self.play_round():
                score += 1

        print("\nGame Over!")
        print(f"Your final score is: {score} out of {rounds}")
        if score > rounds / 2:
            print("Congratulations, you won!")
        else:
            print("Better luck next time!")



class NumberGuess(Game):
    def _init_(self):
        super()._init_("Number Guess", "Guessing the computer's number")

    def play(self):
        secret_number = random.randint(1, 99)
        print("I am thinking of a number between 1 and 99...")

        while True:
            guess = int(input("Enter a guess: "))
            if guess == secret_number:
                print("Congratulations! You guessed the number.")
                break
            elif guess < secret_number:
                print("Your guess is too low.")
            else:
                print("Your guess is too high.")

class GameEngine:
    def _init_(self):
        self.games = []

    def add_game(self, game):
        self.games.append(game)

    def menu(self):
        print("Available Games:")
        for i, game in enumerate(self.games, 1):
            print(f"{i}. {game.name}: {game.description}")

        while True:
            choice = input("Enter the number of the game you want to play (or 'q' to quit): ")
            if choice == 'q':
                break

            try:
                choice = int(choice)
                if 1 <= choice <= len(self.games):
                    self.games[choice - 1].start()  # Call the start method of the chosen game
                else:
                    print("Invalid choice. Please try again.")
            except ValueError:
                print("Invalid input. Please enter a number.")

# Create the game engine and add games
c1 = GameEngine()
c1.add_game(HighLow())
c1.add_game(NumberGuess())

# Run the menu
c1.menu()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 131
#     129 # Create the game engine and add games
#     130 c1 = GameEngine()
# --> 131 c1.add_game(HighLow())
#     132 c1.add_game(NumberGuess())
#     134 # Run the menu
#
# Cell In[3], line 108, in GameEngine.add_game(self, game)
#     107 def add_game(self, game):
# --> 108     self.games.append(game)
#
# AttributeError: 'GameEngine' object has no attribute 'games'

# %%
from abc import ABC, abstractmethod
import random

# Abstract base class
class Games(ABC):
    def __init__(self, player_name):
        self.player_name = player_name
        self.score = 0
    
    @abstractmethod
    def play(self):
        pass
    
    def is_over(self):
        pass

# High-Low Game class
class High_low(Games):
    def __init__(self, player_name):
        super().__init__(player_name)  # Initialize parent class (Games)
        self.count = 0
    
    def play(self):
        while self.count < 3:
            self.count += 1
            self.comp_num = random.randint(1, 100)
            self.my_num = random.randint(1, 100)
            print('Your number is:', self.my_num)
            guess = input("Guess whether your number is higher or lower than the computer's number: ").lower()
            print('Computer number is:', self.comp_num)

            if guess == 'higher' and self.my_num > self.comp_num:
                print('You are right!')
                self.score += 1
            elif guess == 'lower' and self.my_num < self.comp_num:
                print('You are right!')
                self.score += 1
            else:
                print('You are wrong.')
            
            print(f'Your score is: {self.score}')
        
        print('Thanks for playing!')
        print(f'Good job! Your final score is {self.score}')

    def is_over(self):
        return self.count >= 3

# Guess Number Game class
class GuessNumber(Games):
    def __init__(self, player_name):
        super().__init__(player_name)  # Initialize parent class (Games)
        self.user_attempt = 0
        self.allowed_attempt = 5
    
    def play(self):
        num = random.randint(0, 99)
        while self.user_attempt < self.allowed_attempt:
            print(f"Remaining attempts: {self.allowed_attempt - self.user_attempt}")
            self.user_attempt += 1
            guess = int(input("Enter your guess: "))
            
            if guess == num:
                print("Congratulations, your guess is correct!")
                break
            elif guess < num:
                print(f"{self.player_name}, your guess is too low.")
            elif guess > num:
                print(f"{self.player_name}, your guess is too high.")
            
            if self.user_attempt >= self.allowed_attempt:
                print(f"{self.player_name}, you lost! The number was {num}.")
    
    def is_over(self):
        return self.user_attempt >= self.allowed_attempt

# Class to choose and play a game
class Choose_game:
    def __init__(self):
        pass
    
    def game_choice(self):
        print("Welcome to the Game Engine!")
        print("1. High Low Game")
        print("2. Guess the Number Game")
        
        player_name = input("Enter your name: ")

        while True:
            choice = input("Please choose a game (1 or 2): ")

            if choice == '1':
                game = High_low(player_name)
                game.play()
                break  # Exit the loop after the game finishes
            elif choice == '2':
                game = GuessNumber(player_name)
                game.play()
                break  # Exit the loop after the game finishes
            else:
                print("Invalid choice, please select 1 or 2.")

# Start the game engine
choose = Choose_game()  # Instantiate the Choose_game class
choose.game_choice()  # Call the game_choice method
# Out:
# Welcome to the Game Engine!
# 1. High Low Game
# 2. Guess the Number Game
# Invalid choice, please select 1 or 2.
# Invalid choice, please select 1 or 2.
# Invalid choice, please select 1 or 2.
# Invalid choice, please select 1 or 2.
# Your number is: 91
# Computer number is: 49
# You are right!
# Your score is: 1
# Your number is: 80
# Computer number is: 31
# You are wrong.
# Your score is: 1
# Your number is: 33
# Computer number is: 5
# You are right!
# Your score is: 2
# Thanks for playing!
# Good job! Your final score is 2

# %%
import random

class Game:
    def _init_(self, name, description):
        self.name = name
        self.description = description

    def get_info(self):
        print(f"Game: {self.name}")
        print(f"Description: {self.description}")

    def start(self):
        self.play()


class HighLow(Game):
    def _init_(self):
        super()._init_("High Low", "Guess if your number is higher than or lower than the computer's.")

    def play(self):
        self.game()

    def welcome_message(self):
        print("Welcome to the High-Low Game!")
        print("Guess if your number is higher or lower than the computer's.")

    def generate_numbers(self):
        # Generates a number for the player and the computer
        player_number = random.randint(1, 100)
        computer_number = random.randint(1, 100)
        return player_number, computer_number

    def get_player_guess(self):
        # Prompts the player for a guess
        guess = input("Do you think your number is 'higher' or 'lower' than the computer's number? ").strip().lower()
        return guess

    def check_guess(self, player_number, computer_number, guess):
        # Check if the player's guess is correct
        if guess == "higher":
            return player_number > computer_number
        elif guess == "lower":
            return player_number < computer_number
        else:
            print("Invalid guess. Please enter 'higher' or 'lower'.")
            return None

    def play_round(self):
        # Play a single round with consistent player and computer numbers
        player_number, computer_number = self.generate_numbers()
        print(f"\nYour number is: {player_number}")
        guess = self.get_player_guess()

        is_correct = self.check_guess(player_number, computer_number, guess)
        if is_correct is None:
            print("Invalid guess. Try again.")
            return False  # No points awarded for invalid input
        elif is_correct:
            print("Correct guess! You scored a point.")
            return True
        else:
            print("Incorrect guess.")
            print(f"The computer's number was: {computer_number}")  # Reveal computer's number after each guess
            return False

    def game(self):
        rounds = 5
        score = 0
        self.welcome_message()

        for round_num in range(1, rounds + 1):
            print(f"\nRound {round_num}")
            if self.play_round():
                score += 1

        print("\nGame Over!")
        print(f"Your final score is: {score} out of {rounds}")
        if score > rounds / 2:
            print("Congratulations, you won!")
        else:
            print("Better luck next time!")



class NumberGuess(Game):
    def _init_(self):
        super()._init_("Number Guess", "Guessing the computer's number")

    def play(self):
        secret_number = random.randint(1, 99)
        print("I am thinking of a number between 1 and 99...")

        while True:
            guess = int(input("Enter a guess: "))
            if guess == secret_number:
                print("Congratulations! You guessed the number.")
                break
            elif guess < secret_number:
                print("Your guess is too low.")
            else:
                print("Your guess is too high.")

class GameEngine:
    def _init_(self):
        self.games = []

    def add_game(self, game):
        self.games.append(game)

    def menu(self):
        print("Available Games:")
        for i, game in enumerate(self.games, 1):
            print(f"{i}. {game.name}: {game.description}")

        while True:
            choice = input("Enter the number of the game you want to play (or 'q' to quit): ")
            if choice == 'q':
                break

            try:
                choice = int(choice)
                if 1 <= choice <= len(self.games):
                    self.games[choice - 1].start()  # Call the start method of the chosen game
                else:
                    print("Invalid choice. Please try again.")
            except ValueError:
                print("Invalid input. Please enter a number.")

# Create the game engine and add games
c1 = GameEngine()
c1.add_game(HighLow())
c1.add_game(NumberGuess())

# Run the menu
c1.menu()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 131
#     129 # Create the game engine and add games
#     130 c1 = GameEngine()
# --> 131 c1.add_game(HighLow())
#     132 c1.add_game(NumberGuess())
#     134 # Run the menu
#
# Cell In[5], line 108, in GameEngine.add_game(self, game)
#     107 def add_game(self, game):
# --> 108     self.games.append(game)
#
# AttributeError: 'GameEngine' object has no attribute 'games'

# %%
# from abc import ABC,abstractmethod
# import random
# class Games(ABC):
#     def __init__(self,player_name):
#         self.player_name = player_name
#         self.score = 0
#     @abstractmethod
#     def play(self):
#         pass
#     def is_over(self):
#         pass
# class High_low(Games):
#     def __init__(self,player_name):
#         self.count = 0
#         self.score = 0
#         self.player_name = player_name
#     def play(self):
#         while self.count < 3:
#           self.count += 1
#           self.comp_num = random.randint(1,100)
#           self.my_num = random.randint(1,100)
#           print('your number is:',self.my_num)
#           guess = input("guess weather your num is higher or lower then that of computer's num:")
#           print('computer number is:',self.comp_num)
#           if guess == 'higher' and self.my_num > self.comp_num:
#             print('you are right!')
#             self.score += 1
#             print('your score is:',self.score)
#           elif guess == 'lower' and self.my_num < self.comp_num:
#               print('you are right!')
#               self.score += 1
#               print(f"{self.player_name} your score is:",self.score)
#           else:
#                 print('you are wrong')
#                 print('your score is',self.score)
        
#         print('Thanks for playing')
#         print('Good job! you played very well')
#     def is_over(self):
#         return self.count >=3


# class GuessNumber(Games):
#     def __init__(self, player_name):
#        self.player_name = player_name
#        self.user_attempt = 0
#        self.allowed_attempt = 5
#        self.game_over = False
#        self.invalid_input = False
#     def play(self):
#         num = random.randint(0,99)
#         while self.user_attempt < self.allowed_attempt:
#             print(f"{self.allowed_attempt}-{self.user_attempt}")
#             self.user_attempt+=1
#             try:
#               guess = int(input("Enter your guess (below 50): "))
                
#                 # Enforce guess to be below 50
#               if guess > 50:
#                 print("Your guess should be below 50. Try again.")
#                 continue

#             except ValueError:
#                 print("Invalid input! Please enter a number.")
#                 continue
#             if self.user_attempt >= self.allowed_attempt:
#                 print(f"{self.player_name} you lost")
#                 break
#             if guess == num:
#                 print("congrates your guess is correct")
#                 break
#             elif guess< num:
#                 print(f"{self.player_name} your guess is too low")
#             elif guess > num:
#                 print(f"{self.player_name} your guess is too high")
#             else: 
#                 print("invalid input")
            
#     def is_over(self):
#         return self.game_over 
    
# class Choose_game:
#     def __init__(self):
#         pass
#     def game_choice():
#         print("Welcome to the Game Engine!")
#         print("1. High Low Game")
#         print("2. Guess the Number Game")
#         choice = input("Please choose a game (1 or 2): ")

#         player_name = input("Enter your name: ")

#         if choice == '1':
#             game = High_low(player_name)
#             game.play()
#         elif choice == '2':
#             game = GuessNumber(player_name)
#             game.play()
#         else:
#             print("Invalid choice, please select 1 or 2.")
#             game_choice()

#     # Start the game engine
# choose = Choose_game
# choose.game_choice()
